# %%
#Load and Setup

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import confusion_matrix, classification_report
from scipy.stats import randint
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.decomposition import PCA
from sklearn.metrics import plot_roc_curve

from imblearn.over_sampling import SMOTE

# %%
df = pd.read_csv('machine_event.csv', sep = ';')
df['date'] = pd.to_datetime(df.date, format="%m/%d/%Y")

# %%
import statsmodels.api as sm
from statsmodels.sandbox.regression.predstd import wls_prediction_std

# %%
X = df.drop(['event', 'machine', 'date'], axis=1)
y = df.event

# %%
X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    test_size=0.25,
                                                    random_state=42,
                                                    stratify = y)

# %%
model1 = sm.OLS(y, X)
result=model1.fit()
print(result.summary())

# %% [markdown]
# Select only features with p < 0.05, 1 by 1 by eliminating the highest p value

# %%
model2 = sm.OLS(y, X[['feature1', 'feature3', 'feature4', 'feature5', 'feature6', 'feature7', 'feature8', 'feature9']])
result2 = model2.fit()
print(result2.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                  event   R-squared (uncentered):                   0.020
# Model:                            OLS   Adj. R-squared (uncentered):              0.020
# Method:                 Least Squares   F-statistic:                              357.2
# Date:                Wed, 26 May 2021   Prob (F-statistic):                        0.00
# Time:                        23:47:27   Log-Likelihood:                      2.6459e+05
# No. Observations:              124494   AIC:                                 -5.292e+05
# Df Residuals:                  124487   BIC:                                 -5.291e+05
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# feature1   -9.957e-07   4.43e-07     -2.247      0.025   -1.86e-06   -1.27e-07
# feature3    7.701e-10   5.29e-10      1.457      0.145   -2.66e-10    1.81e-09
# feature4    1.483e-12      1e-12      1.481      0.139    -4.8e-13    3.45e-12
# feature5    9.355e-06   4.94e-06      1.894      0.058   -3.27e-07     1.9e-05
# feature6       0.0001   3.42e-06     39.636      0.000       0.000       0.000
# feature7    7.479e-05   3.63e-06     20.580      0.000    6.77e-05    8.19e-05
# feature8    3.827e-07   3.83e-08      9.987      0.000    3.08e-07    4.58e-07
# feature9       0.0002   5.13e-06     39.636      0.000       0.000       0.000
# ==============================================================================
# Omnibus:                   335058.264   Durbin-Watson:                   2.003
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       6804770062.639
# Skew:                          33.438   Prob(JB):                         0.00
# Kurtosis:                    1146.396   Cond. No.                     6.87e+22
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The smallest eigenvalue is 5.26e-25. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
model3 = sm.OLS(y, X[['feature1', 'feature4', 'feature5', 'feature6', 'feature7', 'feature8', 'feature9']])
result3 = model3.fit()
print(result3.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                  event   R-squared (uncentered):                   0.020
# Model:                            OLS   Adj. R-squared (uncentered):              0.020
# Method:                 Least Squares   F-statistic:                              416.4
# Date:                Wed, 26 May 2021   Prob (F-statistic):                        0.00
# Time:                        23:48:00   Log-Likelihood:                      2.6458e+05
# No. Observations:              124494   AIC:                                 -5.292e+05
# Df Residuals:                  124488   BIC:                                 -5.291e+05
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# feature1   -9.826e-07   4.43e-07     -2.218      0.027   -1.85e-06   -1.14e-07
# feature4    2.511e-12   7.11e-13      3.530      0.000    1.12e-12     3.9e-12
# feature5    1.163e-05   4.69e-06      2.480      0.013    2.44e-06    2.08e-05
# feature6       0.0001   3.42e-06     39.645      0.000       0.000       0.000
# feature7      7.5e-05   3.63e-06     20.655      0.000    6.79e-05    8.21e-05
# feature8    3.832e-07   3.83e-08     10.000      0.000    3.08e-07    4.58e-07
# feature9       0.0002   5.13e-06     39.645      0.000       0.000       0.000
# ==============================================================================
# Omnibus:                   335047.058   Durbin-Watson:                   2.003
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       6803424803.883
# Skew:                          33.435   Prob(JB):                         0.00
# Kurtosis:                    1146.283   Cond. No.                     1.29e+22
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The smallest eigenvalue is 1.5e-23. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# Eliminated : feature 2 and 3

# %%
df2 = df[['feature1', 'feature4', 'feature5', 'feature6', 'feature7', 'feature8', 'feature9', 'event']]
df2
# Out:
#         feature1   feature4  feature5  feature6  feature7  feature8  feature9  \
# 0              0  215630672         6         0        52        56         0
# 1              3   61370680         6         0         0         0         0
# 2              0  173295968        12         0         0         0         0
# 3              0   79694024         6         0         0         0         0
# 4              0  135970480        15         0         0         0         0
# ...          ...        ...       ...       ...       ...       ...       ...
# 124489         0   18310224        10         8         0         0        12
# 124490       107  172556680        11         0         4        96         0
# 124491         0   19029120        11         0         0      4832         0
# 124492         0  226953408        12         0         0         0         0
# 124493         0   17572840        10         0         0         0         0
#
#         event
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 124489      0
# 124490      0
# 124491      0
# 124492      0
# 124493      0
#
# [124494 rows x 8 columns]

# %% [markdown]
# # Multicolinearity

# %%
df2.corr(method='pearson')
# Out:
#           feature1  feature4  feature5  feature6  feature7  feature8  \
# feature1  1.000000  0.003702 -0.006696 -0.001884  0.097452 -0.002617
# feature4  0.003702  1.000000 -0.003370  0.000151  0.001837 -0.004248
# feature5 -0.006696 -0.003370  1.000000 -0.009384 -0.009773 -0.013999
# feature6 -0.001884  0.000151 -0.009384  1.000000  0.045631  0.141367
# feature7  0.097452  0.001837 -0.009773  0.045631  1.000000  0.146593
# feature8 -0.002617 -0.004248 -0.013999  0.141367  0.146593  1.000000
# feature9 -0.001884  0.000151 -0.009384  1.000000  0.045631  0.141367
# event    -0.000948  0.001984  0.002270  0.119055  0.067398  0.052902
#
#           feature9     event
# feature1 -0.001884 -0.000948
# feature4  0.000151  0.001984
# feature5 -0.009384  0.002270
# feature6  1.000000  0.119055
# feature7  0.045631  0.067398
# feature8  0.141367  0.052902
# feature9  1.000000  0.119055
# event     0.119055  1.000000

# %% [markdown]
# Eliminate either features that correlated to each other. close to -1 or 1

# %% [markdown]
# safe.

# %%
X = df2.drop(['event'], axis=1)
y = df2.event

# %%
X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    test_size=0.25,
                                                    random_state=42,
                                                    stratify = y)

# %%
sscaler = StandardScaler()
X_train_sscaled = sscaler.fit_transform(X_train)
X_test_sscaled = sscaler.transform(X_test)

# %%
#instiate logreg model
logreg = LogisticRegression()

# fit logreg to the train set
logreg.fit(X_train_sscaled, y_train)
logregpred = logreg.predict(X_test_sscaled)
logregperf = logreg.score(X_test_sscaled, y_test)*100
logregperf
# Out:
# 99.91003727027375

# %%
confusion_matrix(y_test, logregpred)
# Out:
# array([[31096,     1],
#        [   27,     0]], dtype=int64)

# %%
smote = SMOTE(sampling_strategy='minority')
X_sm, y_sm = smote.fit_resample(X, y)

# %%
X_sm_train, X_sm_test, y_sm_train, y_sm_test = train_test_split(X_sm,
                                                    y_sm,
                                                    test_size=0.2,
                                                    random_state=42,
                                                    stratify = y_sm)

# %%
sscaler = StandardScaler()
X_train_smsscaled = sscaler.fit_transform(X_sm_train)
X_test_smsscaled = sscaler.transform(X_sm_test)

# %%
logregsm = LogisticRegression()

#fit logreg to the train set
logregsm.fit(X_train_smsscaled, y_sm_train)
logregsmpred = logregsm.predict(X_test_smsscaled)
logregsmperf = logregsm.score(X_test_smsscaled, y_sm_test)*100
logregsmperf
# Out:
# 83.2703593536458

# %%
confusion_matrix(y_sm_test, logregsmpred)
# Out:
# array([[24173,   705],
#        [ 7619, 17259]], dtype=int64)

# %%
print(classification_report(y_sm_test, logregsmpred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.97      0.85     24878
#            1       0.96      0.69      0.81     24878
#
#     accuracy                           0.83     49756
#    macro avg       0.86      0.83      0.83     49756
# weighted avg       0.86      0.83      0.83     49756

# %%
X_train_sscaled2 = sscaler.transform(X_train)
X_test_sscaled2 = sscaler.transform(X_test)

# %%
realpred1 = logregsm.predict(X_test_sscaled2)

# %%
print(classification_report(y_test, realpred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99     31097
#            1       0.01      0.48      0.03        27
#
#     accuracy                           0.97     31124
#    macro avg       0.51      0.73      0.51     31124
# weighted avg       1.00      0.97      0.98     31124

# %% [markdown]
# # the model did not improve after eliminating unsignificant features
